# %%
# %matplotlib inline
import pandas as pd

# %%
# %%sh
# ls
# Out:
# Untitled.ipynb
# gender_submission.csv
# test.csv
# train.csv

# %%
df_train=pd.read_csv('./train.csv')

# %%
df_train.hist(figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12161c278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121e5eb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121ea10f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121ed06a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121f00c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121f3d240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121f6d7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121f9edd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121f9ee10>]],
#       dtype=object)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
#
# Drop Column: PassengerId, Name, Ticket, Cabin
# Drop Row: Age, Embarked
# Convert Categorical data to numeric data: Sex, Embarked

# %%
#Drop Column: PassengerId, Name, Ticket, Cabin
df1 = df_train.drop(['PassengerId','Name', 'Ticket', 'Cabin'],axis=1)
#Drop Row: Age, Embarked
df2 = df1.dropna()
#Convert Categorical data to numeric data: Sex, Embarked

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
# Survived    712 non-null int64
# Pclass      712 non-null int64
# Sex         712 non-null object
# Age         712 non-null float64
# SibSp       712 non-null int64
# Parch       712 non-null int64
# Fare        712 non-null float64
# Embarked    712 non-null object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB

# %%
df2.to_numpy()
# Out:
# array([[0, 3, 'male', ..., 0, 7.25, 'S'],
#        [1, 1, 'female', ..., 0, 71.2833, 'C'],
#        [1, 3, 'female', ..., 0, 7.925, 'S'],
#        ...,
#        [1, 1, 'female', ..., 0, 30.0, 'S'],
#        [1, 1, 'male', ..., 0, 30.0, 'C'],
#        [0, 3, 'male', ..., 0, 7.75, 'Q']], dtype=object)

# %%
for i in df2.iterrows():
   if i[1]['Sex'] == 'male':
    df2['sex_cat'][i[0]]
# Out:
# 0 male
# 4 male
# 6 male
# 7 male
# 12 male
# 13 male
# 16 male
# 20 male
# 21 male
# 23 male
# 27 male
# 30 male
# 33 male
# 34 male
# 35 male
# 37 male
# 50 male
# 51 male
# 54 male
# 57 male
# 59 male
# 60 male
# 62 male
# 63 male
# 67 male
# 69 male
# 70 male
# 72 male
# 73 male
# 74 male
# 75 male
# 78 male
# 80 male
# 81 male
# 83 male
# 86 male
# 89 male
# 90 male
# 91 male
# 92 male
# 93 male
# 94 male
# 96 male
# 97 male
# 99 male
# 102 male
# 103 male
# 104 male
# 105 male
# 108 male
# 110 male
# 112 male
# 115 male
# 116 male
# 117 male
# 118 male
# 120 male
# 122 male
# 124 male
# 125 male
# 127 male
# 129 male
# 130 male
# 131 male
# 134 male
# 135 male
# 137 male
# 138 male
# 139 male
# 143 male
# 144 male
# 145 male
# 146 male
# 148 male
# 149 male
# 150 male
# 152 male
# 153 male
# 155 male
# 157 male
# 160 male
# 162 male
# 163 male
# 164 male
# 165 male
# 169 male
# 170 male
# 171 male
# 173 male
# 174 male
# 175 male
# 178 male
# 179 male
# 182 male
# 183 male
# 187 male
# 188 male
# 189 male
# 191 male
# 193 male
# 197 male
# 200 male
# 202 male
# 203 male
# 204 male
# 206 male
# 207 male
# 209 male
# 210 male
# 212 male
# 213 male
# 217 male
# 219 male
# 220 male
# 221 male
# 222 male
# 224 male
# 225 male
# 226 male
# 227 male
# 228 male
# 231 male
# 232 male
# 234 male
# 236 male
# 238 male
# 239 male
# 242 male
# 243 male
# 244 male
# 245 male
# 248 male
# 249 male
# 252 male
# 253 male
# 261 male
# 262 male
# 263 male
# 265 male
# 266 male
# 267 male
# 271 male
# 273 male
# 278 male
# 280 male
# 281 male
# 282 male
# 283 male
# 285 male
# 286 male
# 287 male
# 288 male
# 292 male
# 294 male
# 296 male
# 302 male
# 305 male
# 308 male
# 313 male
# 314 male
# 317 male
# 320 male
# 321 male
# 326 male
# 331 male
# 332 male
# 333 male
# 336 male
# 338 male
# 339 male
# 340 male
# 342 male
# 343 male
# 344 male
# 348 male
# 349 male
# 350 male
# 352 male
# 353 male
# 355 male
# 360 male
# 361 male
# 363 male
# 365 male
# 370 male
# 371 male
# 372 male
# 373 male
# 377 male
# 378 male
# 379 male
# 382 male
# 385 male
# 386 male
# 390 male
# 391 male
# 392 male
# 395 male
# 397 male
# 398 male
# 400 male
# 401 male
# 403 male
# 405 male
# 406 male
# 407 male
# 408 male
# 414 male
# 418 male
# 421 male
# 422 male
# 424 male
# 429 male
# 430 male
# 433 male
# 434 male
# 438 male
# 439 male
# 441 male
# 442 male
# 445 male
# 447 male
# 449 male
# 450 male
# 452 male
# 453 male
# 455 male
# 456 male
# 460 male
# 461 male
# 462 male
# 463 male
# 465 male
# 467 male
# 471 male
# 476 male
# 477 male
# 478 male
# 480 male
# 482 male
# 484 male
# 487 male
# 488 male
# 489 male
# 491 male
# 492 male
# 493 male
# 494 male
# 499 male
# 500 male
# 505 male
# 508 male
# 509 male
# 510 male
# 512 male
# 514 male
# 515 male
# 519 male
# 521 male
# 525 male
# 528 male
# 529 male
# 532 male
# 536 male
# 543 male
# 544 male
# 545 male
# 548 male
# 549 male
# 550 male
# 551 male
# 553 male
# 555 male
# 561 male
# 562 male
# 565 male
# 566 male
# 569 male
# 570 male
# 572 male
# 574 male
# 575 male
# 579 male
# 582 male
# 583 male
# 586 male
# 587 male
# 588 male
# 590 male
# 592 male
# 594 male
# 595 male
# 597 male
# 599 male
# 603 male
# 604 male
# 605 male
# 606 male
# 607 male
# 614 male
# 616 male
# 619 male
# 620 male
# 621 male
# 622 male
# 623 male
# 624 male
# 625 male
# 626 male
# 628 male
# 630 male
# 631 male
# 632 male
# 636 male
# 637 male
# 640 male
# 645 male
# 646 male
# 647 male
# 652 male
# 655 male
# 658 male
# 659 male
# 660 male
# 661 male
# 662 male
# 663 male
# 664 male
# 665 male
# 666 male
# 668 male
# 671 male
# 672 male
# 673 male
# 675 male
# 676 male
# 679 male
# 681 male
# 682 male
# 683 male
# 684 male
# 685 male
# 686 male
# 687 male
# 688 male
# 690 male
# 693 male
# 694 male
# 695 male
# 696 male
# 698 male
# 699 male
# 701 male
# 703 male
# 704 male
# 705 male
# 707 male
# 712 male
# 713 male
# 714 male
# 715 male
# 719 male
# 721 male
# 722 male
# 723 male
# 724 male
# 725 male
# 728 male
# 731 male
# 733 male
# 734 male
# 735 male
# 737 male
# 741 male
# 743 male
# 744 male
# 745 male
# 746 male
# 748 male
# 749 male
# 751 male
# 752 male
# 753 male
# 755 male
# 756 male
# 757 male
# 758 male
# 761 male
# 762 male
# 764 male
# 769 male
# 770 male
# 771 male
# 775 male
# 782 male
# 784 male
# 785 male
# 787 male
# 788 male
# 789 male
# 791 male
# 794 male
# 795 male
# 798 male
# 800 male
# 802 male
# 803 male
# 804 male
# 805 male
# 806 male
# 808 male
# 810 male
# 811 male
# 812 male
# 814 male
# 817 male
# 818 male
# 819 male
# 821 male
# 822 male
# 824 male
# 827 male
# 831 male
# 833 male
# 834 male
# 836 male
# 838 male
# 840 male
# 841 male
# 843 male
# 844 male
# 845 male
# 847 male
# 848 male
# 850 male
# 851 male
# 857 male
# 860 male
# 861 male
# 864 male
# 867 male
# 869 male
# 870 male
# 872 male
# 873 male
# 876 male
# 877 male
# 881 male
# 883 male
# 884 male
# 886 male
# 889 male
# 890 male

# %%
df3=df2
df3['sex_cat_old']=0
for i in df3.iterrows():
    if i[1]['Sex']
.astype('category').cat.codes
df3
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# 13          0       3    male  39.0      1      5   31.2750        S
# 14          0       3  female  14.0      0      0    7.8542        S
# 15          1       2  female  55.0      0      0   16.0000        S
# 16          0       3    male   2.0      4      1   29.1250        Q
# 18          0       3  female  31.0      1      0   18.0000        S
# 20          0       2    male  35.0      0      0   26.0000        S
# 21          1       2    male  34.0      0      0   13.0000        S
# 22          1       3  female  15.0      0      0    8.0292        Q
# 23          1       1    male  28.0      0      0   35.5000        S
# 24          0       3  female   8.0      3      1   21.0750        S
# 25          1       3  female  38.0      1      5   31.3875        S
# 27          0       1    male  19.0      3      2  263.0000        S
# 30          0       1    male  40.0      0      0   27.7208        C
# 33          0       2    male  66.0      0      0   10.5000        S
# 34          0       1    male  28.0      1      0   82.1708        C
# 35          0       1    male  42.0      1      0   52.0000        S
# 37          0       3    male  21.0      0      0    8.0500        S
# 38          0       3  female  18.0      2      0   18.0000        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 856         1       1  female  45.0      1      1  164.8667        S
# 857         1       1    male  51.0      0      0   26.5500        S
# 858         1       3  female  24.0      0      3   19.2583        C
# 860         0       3    male  41.0      2      0   14.1083        S
# 861         0       2    male  21.0      1      0   11.5000        S
# 862         1       1  female  48.0      0      0   25.9292        S
# 864         0       2    male  24.0      0      0   13.0000        S
# 865         1       2  female  42.0      0      0   13.0000        S
# 866         1       2  female  27.0      1      0   13.8583        C
# 867         0       1    male  31.0      0      0   50.4958        S
# 869         1       3    male   4.0      1      1   11.1333        S
# 870         0       3    male  26.0      0      0    7.8958        S
# 871         1       1  female  47.0      1      1   52.5542        S
# 872         0       1    male  33.0      0      0    5.0000        S
# 873         0       3    male  47.0      0      0    9.0000        S
# 874         1       2  female  28.0      1      0   24.0000        C
# 875         1       3  female  15.0      0      0    7.2250        C
# 876         0       3    male  20.0      0      0    9.8458        S
# 877         0       3    male  19.0      0      0    7.8958        S
# 879         1       1  female  56.0      0      1   83.1583        C
# 880         1       2  female  25.0      0      1   26.0000        S
# 881         0       3    male  33.0      0      0    7.8958        S
# 882         0       3  female  22.0      0      0   10.5167        S
# 883         0       2    male  28.0      0      0   10.5000        S
# 884         0       3    male  25.0      0      0    7.0500        S
# 885         0       3  female  39.0      0      5   29.1250        Q
# 886         0       2    male  27.0      0      0   13.0000        S
# 887         1       1  female  19.0      0      0   30.0000        S
# 889         1       1    male  26.0      0      0   30.0000        C
# 890         0       3    male  32.0      0      0    7.7500        Q
#
# [712 rows x 8 columns]

# %%
df4=df2
df4['sex_cat'] = df4['Sex'].astype('category').cat.codes
df4['Embarked_cat'] = df4['Embarked'].astype('category').cat.codes
df4.head()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  sex_cat  \
# 0         0       3    male  22.0      1      0   7.2500        S        1
# 1         1       1  female  38.0      1      0  71.2833        C        0
# 2         1       3  female  26.0      0      0   7.9250        S        0
# 3         1       1  female  35.0      1      0  53.1000        S        0
# 4         0       3    male  35.0      0      0   8.0500        S        1
#
#    Embarked_cat
# 0             2
# 1             0
# 2             2
# 3             2
# 4             2

# %%
df4.keys()
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'sex_cat', 'Embarked_cat'],
#       dtype='object')

# %%
header=['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'sex_cat', 'Embarked_cat']
df5=df4[header]
df5.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  sex_cat  Embarked_cat
# 0         0       3  22.0      1      0   7.2500        1             2
# 1         1       1  38.0      1      0  71.2833        0             0
# 2         1       3  26.0      0      0   7.9250        0             2
# 3         1       1  35.0      1      0  53.1000        0             2
# 4         0       3  35.0      0      0   8.0500        1             2

# %%
yx=df5.to_numpy()

# %%
yx.shape
# Out:
# (712, 8)

# %%
x_train=yx[:,1:]
y_tain=yx[:,1]

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
import numpy as p
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
yx
# Out:
# array([[ 0.    ,  3.    , 22.    , ...,  7.25  ,  1.    ,  2.    ],
#        [ 1.    ,  1.    , 38.    , ..., 71.2833,  0.    ,  0.    ],
#        [ 1.    ,  3.    , 26.    , ...,  7.925 ,  0.    ,  2.    ],
#        ...,
#        [ 1.    ,  1.    , 19.    , ..., 30.    ,  0.    ,  2.    ],
#        [ 1.    ,  1.    , 26.    , ..., 30.    ,  1.    ,  0.    ],
#        [ 0.    ,  3.    , 32.    , ...,  7.75  ,  1.    ,  1.    ]])

# %%
gb = GradientBoostingClassifier(n_estimators=20, learning_rate = 0.5, max_features=2, max_depth = 2, random_state = 0)
gb.fit(X_train, y_train)
np.average( cross_val_score(gb, X_train, y_train, cv=5) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-5d4bd411d1c7> in <module>
#       1 gb = GradientBoostingClassifier(n_estimators=20, learning_rate = 0.5, max_features=2, max_depth = 2, random_state = 0)
# ----> 2 gb.fit(X_train, y_train)
#       3 np.average( cross_val_score(gb, X_train, y_train, cv=5) )
#
# NameError: name 'X_train' is not defined

# %%
header
# Out:
# ['Survived',
#  'Pclass',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare',
#  'sex_cat',
#  'Embarked_cat']

# %%
yx
# Out:
# array([[ 0.    ,  3.    , 22.    , ...,  7.25  ,  1.    ,  2.    ],
#        [ 1.    ,  1.    , 38.    , ..., 71.2833,  0.    ,  0.    ],
#        [ 1.    ,  3.    , 26.    , ...,  7.925 ,  0.    ,  2.    ],
#        ...,
#        [ 1.    ,  1.    , 19.    , ..., 30.    ,  0.    ,  2.    ],
#        [ 1.    ,  1.    , 26.    , ..., 30.    ,  1.    ,  0.    ],
#        [ 0.    ,  3.    , 32.    , ...,  7.75  ,  1.    ,  1.    ]])

# %%
yx.shape
# Out:
# (712, 8)

# %%
X_train=yx[:,1:]
y_train=yx[:,0]

# %%
X_train.shape
# Out:
# (712, 7)

# %%
y_train.shape
# Out:
# (712,)

# %% [markdown]
# # Supervised Learning

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
gb = GradientBoostingClassifier(n_estimators=20, learning_rate = 0.5, max_features=2, max_depth = 2, random_state = 0)
gb.fit(X_train, y_train)
np.average( cross_val_score(gb, X_train, y_train, cv=5) )
# Out:
# 0.8007261941933802

# %%
header
# Out:
# ['Survived',
#  'Pclass',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare',
#  'sex_cat',
#  'Embarked_cat']

# %%
X_train[:10,:]
# Out:
# array([[ 3.    , 22.    ,  1.    ,  0.    ,  7.25  ,  1.    ,  2.    ],
#        [ 1.    , 38.    ,  1.    ,  0.    , 71.2833,  0.    ,  0.    ],
#        [ 3.    , 26.    ,  0.    ,  0.    ,  7.925 ,  0.    ,  2.    ],
#        [ 1.    , 35.    ,  1.    ,  0.    , 53.1   ,  0.    ,  2.    ],
#        [ 3.    , 35.    ,  0.    ,  0.    ,  8.05  ,  1.    ,  2.    ],
#        [ 1.    , 54.    ,  0.    ,  0.    , 51.8625,  1.    ,  2.    ],
#        [ 3.    ,  2.    ,  3.    ,  1.    , 21.075 ,  1.    ,  2.    ],
#        [ 3.    , 27.    ,  0.    ,  2.    , 11.1333,  0.    ,  2.    ],
#        [ 2.    , 14.    ,  1.    ,  0.    , 30.0708,  0.    ,  0.    ],
#        [ 3.    ,  4.    ,  1.    ,  1.    , 16.7   ,  0.    ,  2.    ]])

# %%
gb.predict(X_train[:10,:])
# Out:
# array([0., 1., 1., 1., 0., 0., 0., 1., 1., 1.])

# %%
y_train[:10]
# Out:
# array([0., 1., 1., 1., 0., 0., 0., 1., 1., 1.])

# %% [markdown]
# # Deploy ML

# %%
import pickle
filename = 'titanic.model'
pickle.dump(gb, open(filename, 'wb'))

loaded_model = pickle.load(open(filename, 'rb'))
loaded_model.predict(X_train[:10,:])
# Out:
# array([0., 1., 1., 1., 0., 0., 0., 1., 1., 1.])
